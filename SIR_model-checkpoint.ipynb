# %%
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Let’s run the basic SIR model

# %%
# describe the model
def deriv(y, t, N, beta, k, delta, gamma):
    S, E, I, R, D = y
    sigma = 1 - (I**(1/2) / N**(1/2))
    dSdt = -sigma * beta * S * I / N + (1/365)*R*0.3
    dEdt = sigma * beta * S * I / N - delta * E 
    dIdt = delta * E - k * I
    dRdt = k * I - I*gamma - (1/365)*R*0.3
    dDdt = I*k*gamma
    return dSdt, dEdt, dIdt, dRdt, dDdt

# %%
# describe the parameters
N =  10000000               # population             
beta = 2.2                  # reproduction
gamma = 0.02                # mortality rate (10 000 deaths, 500 000 cases)
k=1/7                       #
delta = 1.0/5.0
S0, E0, I0, R0, D0 = N-1, 1, 0, 0, 0  # initial conditions: one infected, rest susceptible

# %%
t = np.linspace(0, 364, 365) # Grid of time points (in days)
y0 = S0, E0, I0, R0, D0 # Initial conditions vector

# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(N, beta, k, delta, gamma))
S, E, I, R, D = ret.T

# %%
def plotsir(t, S, E, I, R, D):
  f, ax = plt.subplots(1,1,figsize=(10,4))
  ax.plot(t, S, 'b', alpha=0.7, linewidth=2, label='Susceptible')
  ax.plot(t, E, 'y', alpha=0.7, linewidth=2, label='Exposed')
  ax.plot(t, I, 'r', alpha=0.7, linewidth=2, label='Infected')
  ax.plot(t, R, 'g', alpha=0.7, linewidth=2, label='Recovered')
  ax.plot(t, D, 'm', alpha=0.7, linewidth=2, label='Dead')

  ax.set_xlabel('Time (days)')

  ax.yaxis.set_tick_params(length=0)
  ax.xaxis.set_tick_params(length=0)
  ax.grid(b=True, which='major', c='w', lw=2, ls='-')
  legend = ax.legend()
  legend.get_frame().set_alpha(0.5)
  for spine in ('top', 'right', 'bottom', 'left'):
      ax.spines[spine].set_visible(False)
  plt.savefig("plot.png")
  plt.show();
    
def plotsirdead(t, E, I, D):
  f, ax = plt.subplots(1,1,figsize=(10,4))
  ax.plot(t, E, 'y', alpha=0.7, linewidth=2, label='Exposed')
  ax.plot(t, I, 'r', alpha=0.7, linewidth=2, label='Infected')   
  ax.plot(t, D, 'm', alpha=0.7, linewidth=2, label='Dead')
    
  ax.set_xlabel('Time (days)')
        
  ax.yaxis.set_tick_params(length=0)
  ax.xaxis.set_tick_params(length=0)
  ax.grid(b=True, which='major', c='w', lw=2, ls='-')
  legend = ax.legend()
  legend.get_frame().set_alpha(0.5)
  for spine in ('top', 'right', 'bottom', 'left'):
        ax.spines[spine].set_visible(False)
  plt.savefig("plotdead.png")
  plt.show();

# %% [markdown]
# plot the graph

# %%
plotsir(t, S, E, I, R, D)
plotsirdead(t,E,I,D)
